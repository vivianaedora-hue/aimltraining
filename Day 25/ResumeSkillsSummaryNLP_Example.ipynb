# %%
#Import all required libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/sample_data/UpdatedResumeDataSet.csv',encoding='utf-8')
df.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
print('\n Columns',df.columns.tolist())
# Out:
#  Columns ['Category', 'Resume']

# %%
sample_df=df.sample(10,random_state=42).reset_index(drop=True)
sample_df
print(sample_df.shape)
# Out:
# (10, 2)

# %%
vectorizer=TfidfVectorizer(stop_words='english')
tfidf_matrix=vectorizer.fit_transform(sample_df['Resume'])
tfidf_matrix.shape
# Out:
# (10, 1125)

# %%
similartiness_matrix=cosine_similarity(tfidf_matrix)
sim_df=pd.DataFrame(similartiness_matrix,index=sample_df['Category']+"__"+sample_df.index.astype(str),
                    columns=sample_df['Category']+"__"+sample_df.index.astype(str))
sim_df.round(2).head(3)
# Out:
#                    Java Developer__0  Java Developer__1  Java Developer__2  \
# Java Developer__0               1.00               0.41               0.24
# Java Developer__1               0.41               1.00               0.22
# Java Developer__2               0.24               0.22               1.00
#
#                    Hadoop__3  Health and fitness__4  \
# Java Developer__0       0.11                   0.06
# Java Developer__1       0.14                   0.03
# Java Developer__2       0.11                   0.07
#
#                    Network Security Engineer__5  Mechanical Engineer__6  \
# Java Developer__0                          0.07                    0.06
# Java Developer__1                          0.05                    0.03
# Java Developer__2                          0.07                    0.07
#
#                    Automation Testing__7  Advocate__8  Health and fitness__9
# Java Developer__0                   0.10         0.11                   0.08
# Java Developer__1                   0.09         0.09                   0.06
# Java Developer__2                   0.08         0.05                   0.03

# %%
resumes={
    "candidate":['Sam','Arsh','Maan'],
    "resume_text":["Python developer skilled in Django,Flask, Rest API and MySql",
                   "Machine learning engineer experience in Python,TensorFlow,NLP and data analysis",
                   "Full stack developer with .net,javascript, React, Node.js and MongoDB experience"]
}

# %%
df=pd.DataFrame(resumes)
df
# Out:
#   candidate                                        resume_text
# 0       Sam  Python developer skilled in Django,Flask, Rest...
# 1      Arsh  Machine learning engineer experience in Python...
# 2      Maan  Full stack developer with .net,javascript, Rea...

# %%
vectorizer=TfidfVectorizer(stop_words='english')
tfidf_matrix=vectorizer.fit_transform(df['resume_text'])
tfidf_matrix.shape
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 26 stored elements and shape (3, 23)>

# %%
similartiness_matrix=cosine_similarity(tfidf_matrix)
sim_df=pd.DataFrame(similartiness_matrix,index=df['candidate'],
                    columns=df['candidate'])
sim_df.round(2)
# Out:
# candidate   Sam  Arsh  Maan
# candidate
# Sam        1.00  0.08  0.08
# Arsh       0.08  1.00  0.07
# Maan       0.08  0.07  1.00

# %%
df.loc[len(df)]=["Zoya","Backend developer skilled in Python, Flask and SQL"]

# %%
df
# Out:
#   candidate                                        resume_text
# 0       Sam  Python developer skilled in Django,Flask, Rest...
# 1      Arsh  Machine learning engineer experience in Python...
# 2      Maan  Full stack developer with .net,javascript, Rea...
# 3      Zoya  Backend developer skilled in Python, Flask and...

# %%
vectorizer=TfidfVectorizer(stop_words='english')
tfidf_matrix=vectorizer.fit_transform(df['resume_text'])
tfidf_matrix.shape
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 32 stored elements and shape (4, 25)>

# %%
similartiness_matrix=cosine_similarity(tfidf_matrix)
sim_df=pd.DataFrame(similartiness_matrix,index=df['candidate'],
                    columns=df['candidate'])
sim_df.round(2)
# Out:
# candidate   Sam  Arsh  Maan  Zoya
# candidate
# Sam        1.00  0.06  0.06  0.42
# Arsh       0.06  1.00  0.08  0.07
# Maan       0.06  0.08  1.00  0.07
# Zoya       0.42  0.07  0.07  1.00
