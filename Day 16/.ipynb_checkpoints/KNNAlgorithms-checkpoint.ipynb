# %% [markdown]
# ## KNN Algorithm in Supervised Machine Learning
# ## KNeighboursClassifier of sklearn library for this one

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
X = np.array([
    [1,3500],
    [2,3200],
    [3,3000],
    [4,2500],
    [5,2300],
    [6,2000],
    [7,2200],
    [2, 3700],
])
y = ['Unfit','Unfit','Unfit','Fit','Fit','Fit','Fit','Unfit']

# %%
# create the model
model=KNeighborsClassifier(n_neighbors=3)

# %%
# train the model
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# predict
new_person = [[4.5, 2600]]
pred = model.predict(new_person)
print("Predicted Result:",pred[0])
# Out:
# Predicted Result: Fit

# %%
#prediction from taking the values from users
exercise_hours= float(input('Enter number of exercise hours'))
cal_intake=float(input('Enter number of calories consumed'))
pred_fu = model.predict([[exercise_hours,cal_intake]])
print(f'exercise hours {exercise_hours}, Calories Intake {cal_intake} You are likely {pred_fu[0]}')
# Out:
# Enter number of exercise hours 3.5
# Enter number of calories consumed 25000
# exercise hours 3.5, Calories Intake 25000.0 You are likely Unfit

# %%
import pandas as pd

# %%
#collect the data
df = pd.read_csv('fruit_data.csv')
df
# Out:
#    Weight  Size   Fruit
# 0     150   7.0   Apple
# 1     160   7.2   Apple
# 2     200   8.0  Orange
# 3     210   8.2  Orange
# 4     180   7.5       ?

# %%
#split the data
X= df[['Weight','Size']]
y = df['Fruit']

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %%
#train the model
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#new_fruit = [[120, 9]]
new_fruit = pd.DataFrame([[120,2]],columns=['Weight','Size'])
pred = model.predict(new_fruit)
print("Predicted result:", pred[0])
# Out:
# Predicted result: Apple

# %%
fruit_weight=float(input('Enter weight of fruit in gram'))
fruit_size = float(input('Enter size of fruit in cm'))
our_fruit=pd.DataFrame([[fruit_weight, fruit_size]],columns=['Weight','Size'])
pred_fruit= model.predict([[fruit_weight,fruit_size]])

print(f'Fruit weight is {fruit_weight}, Fruit Size is: {cal_intake} You are likely an: {pred_fruit[0]}')
# Out:
# Enter weight of fruit in gram 500
# Enter size of fruit in cm 10
# Fruit weight is 500.0, Fruit Size is: 25000.0 You are likely an: Orange
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Download student_grade.csv from GitHub.com
# ## Predict a students grade level (A,B or C)
# ## based on hours studied and assignments completed
# ## using the K-Nearest Neighbors algorithm.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("student_grade.csv")
print(df.head())
# Out:
#    Hours_Studied  Assignments_Completed Grade
# 0            1.5                      1     C
# 1            2.0                      2     C
# 2            3.0                      3     B
# 3            4.0                      4     B
# 4            5.0                      5     A

# %%
X = df[['Hours_Studied', 'Assignments_Completed']]
y = df['Grade']

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %%
# train the model
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# predict
new_student = [[6, 8]]
pred = model.predict(new_student)
print("Predicted Result:",pred[0])
# Out:
# Predicted Result: A
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
